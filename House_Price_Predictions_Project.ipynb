# %% [raw]
# # Project on House Price Prediction

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('kc_house_data.csv')

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
# EDA:matplotlib ,seaborn
# data pre processing:
   # 1. feature  eng : ----null values, numerical, categorical
   # 2. Feature scaling --- -scaling into numerical data ( so we dont have categorical)
  #  3. feature selection -- selecting columns --- ( domain expert)
# model building:  spliting the data ,building model , imporving model ( hyperparametre tuning),
# save and delpoy model

# %%
df.dropna(inplace=True)

# %%
label = df['price']

# %%
label
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
train = df.drop(['id','price','date'],axis=1)

# %%
train.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
df.corr()
# Out:
# <ipython-input-15-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# ...

# %%
corrmat = df.corr()
top_corr_feature = corrmat.index
top_corr_feature
# Out:
# <ipython-input-16-02928e1394e0>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
top_corr_feature = corrmat.index

# %%
plt.figure(figsize=(20,20))
g=sns.heatmap(df[top_corr_feature].corr(),annot=True,cmap="RdYlGn")

# %%
from sklearn.ensemble import ExtraTreesRegressor  #  build a model do prediction give which variable is impacting our depd more
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(train,label)
# Out:
# ExtraTreesRegressor()

# %%
model.feature_importances_
# Out:
# array([0.00771537, 0.03540459, 0.18082308, 0.01240978, 0.00763492,
#        0.04221308, 0.03413971, 0.01018005, 0.23876379, 0.08041557,
#        0.01349309, 0.03684702, 0.00606954, 0.01983616, 0.13489878,
#        0.04818418, 0.07898996, 0.01198133])

# %%
feat_importances = pd.Series(model.feature_importances_, index=train.columns)

# %%
feat_importances
# Out:
# bedrooms         0.007715
# bathrooms        0.035405
# sqft_living      0.180823
# sqft_lot         0.012410
# floors           0.007635
# waterfront       0.042213
# view             0.034140
# condition        0.010180
# grade            0.238764
# sqft_above       0.080416
# sqft_basement    0.013493
# yr_built         0.036847
# yr_renovated     0.006070
# zipcode          0.019836
# lat              0.134899
# long             0.048184
# sqft_living15    0.078990
# sqft_lot15       0.011981
# dtype: float64

# %%
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
col_imp = ['grade','lat','long','sqft_living','waterfront','yr_built']

# %%
train
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0             3       1.00         1180      5650     1.0           0     0
# 1             3       2.25         2570      7242     2.0           0     0
# 2             2       1.00          770     10000     1.0           0     0
# 3             4       3.00         1960      5000     1.0           0     0
# 4             3       2.00         1680      8080     1.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21608         3       2.50         1530      1131     3.0           0     0
# 21609         4       2.50         2310      5813     2.0           0     0
# 21610         2       0.75         1020      1350     2.0           0     0
# 21611         3       2.50         1600      2388     2.0           0     0
# 21612         2       0.75         1020      1076     2.0           0     0
#
# ...

# %%
train[col_imp]
# Out:
#        grade      lat     long  sqft_living  waterfront  yr_built
# 0          7  47.5112 -122.257         1180           0      1955
# 1          7  47.7210 -122.319         2570           0      1951
# 2          6  47.7379 -122.233          770           0      1933
# 3          7  47.5208 -122.393         1960           0      1965
# 4          8  47.6168 -122.045         1680           0      1987
# ...      ...      ...      ...          ...         ...       ...
# 21608      8  47.6993 -122.346         1530           0      2009
# 21609      8  47.5107 -122.362         2310           0      2014
# 21610      7  47.5944 -122.299         1020           0      2009
# 21611      8  47.5345 -122.069         1600           0      2004
# 21612      7  47.5941 -122.299         1020           0      2008
#
# [21613 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train[col_imp], label, test_size=0.3, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor =RandomForestRegressor(n_estimators=500)

# %%
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=500)

# %%
# prediction
y_pred = regressor.predict(train[col_imp])

# %%
y_pred
# Out:
# array([239871.518     , 490021.51666667, 226410.13333333, ...,
#        337226.696     , 423865.39333333, 336616.15      ])

# %%
label
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
# rmse ,r2  for comparing model in regression -- classfication ( confusion matrix)

# %%
from sklearn.metrics import mean_squared_error

from math import sqrt

# %%
rmse= sqrt(mean_squared_error(label,y_pred))

# %%
rmse
# Out:
# 84577.32960645658

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
clf = GradientBoostingRegressor(n_estimators =500)

# %%
clf.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(n_estimators=500)

# %%
y_pred_grid = clf.predict(train[col_imp])#gb

# %%
rmse_grid= sqrt(mean_squared_error(label,y_pred_grid))

# %%
rmse_grid
# Out:
# 108615.84377347291

# %%
rmse
# Out:
# 84577.32960645658

# %%
# rf --- saving the ml model   # joblib ,pickle

# %%
import pickle

# %%
pickle.dump(regressor,open('regressor_model.pkl','wb'))

# %%
load = pickle.load(open('regressor_model.pkl','rb'))

# %%
y_loaded = load.predict(train[col_imp])

# %%
y_loaded
# Out:
# array([239871.518     , 490021.51666667, 226410.13333333, ...,
#        337226.696     , 423865.39333333, 336616.15      ])

# %%
# !pip install xgboost

# %%
import xgboost as xgb

# %%
xgb_Regressor = xgb.XGBRegressor()

# %%
xgb_Regressor.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred_xgb = xgb_Regressor.predict(train[col_imp])

# %%
y_pred_xgb
# Out:
# array([237657.53, 481649.72, 257763.3 , ..., 336324.5 , 439913.53,
#        324751.84], dtype=float32)

# %%
rmse_xgrid= sqrt(mean_squared_error(label,y_pred_xgb))

# %%
rmse_xgrid
# Out:
# 96427.4284052323

# %%
rmse
# Out:
# 84577.32960645658
