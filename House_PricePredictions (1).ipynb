# %% [raw]
# # creating conda environment :
#
#
# conda create --name PricePredictionMay python==3.7
# conda activate PricePredictionMay
#
# conda install -c anaconda ipykernel
# python -m ipykernel install --user --name=PricePredictionMay

# %%
#pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
# csv  - sql - get data sql ( -- sql-python code)

# %%
df= pd.read_csv('kc_house_data.csv')

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
# EDA:matplotlib ,seaborn
# data pre processing:
   # 1. feature  eng : ----null values, numerical, categorical
   # 2. Feature scaling --- -scaling into numerical data ( so we dont have categorical)
  #  3. feature selection -- selecting columns --- ( domain expert)
# model building:  spliting the data ,building model , imporving model ( hyperparametre tuning),
# save and delpoy model

# %%
# !pip install  pandas-profiling
# Out:
# ...
#   Using cached pydantic-2.6.2-py3-none-any.whl (394 kB)
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.14
#     Uninstalling pydantic-1.10.14:
#       Successfully uninstalled pydantic-1.10.14
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dataprep 0.4.5 requires pydantic<2.0,>=1.6, but you have pydantic 2.6.2 which is incompatible.
# ...

# %%
'''# Generating the Profile Report
profile = ProfileReport(df, title='House_Price Prediction', correlations={"cramers": {"calculate": False}}, explorative=True)

# Converting the Profile Report to HTML as a string
html_string = profile.to_html()

# Saving the HTML string to a file
with open("HousePrice_Report.html", "w") as html_file:
    html_file.write(html_string)'''
# Out:
# '# Generating the Profile Report\nprofile = ProfileReport(df, title=\'House_Price Prediction\', correlations={"cramers": {"calculate": False}}, explorative=True)\n\n# Converting the Profile Report to HTML as a string\nhtml_string = profile.to_html()\n\n# Saving the HTML string to a file\nwith open("HousePrice_Report.html", "w") as html_file:\n    html_file.write(html_string)'

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
# !pip install sweetviz
import sweetviz as sv

report = sv.analyze(df)
report.show_html("HousePrice_Report.html")
# Out:
# ...
#                                              |          | [  0%]   00:00 -> (? left)
# Report HousePrice_Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# !pip install dataprep
from dataprep.eda import create_report

create_report(df).show_browser()
# Out:
# ...
#   Using cached pydantic-1.10.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.6.2
#     Uninstalling pydantic-2.6.2:
#       Successfully uninstalled pydantic-2.6.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.6.4 requires pydantic>=2, but you have pydantic 1.10.14 which is incompatible.
# ...
# Computing series-sum-chunk-b248b808a26f0f3e6733ee4b3f01bbd7-a05a0106b8e5d9d30b931de5ccb300cc:   2%|▏         | 80/3777 [00:00<00:11, 321.08it/s]/usr/local/lib/python3.10/dist-packages/dask/core.py:121: RuntimeWarning:
#
# invalid value encountered in divide
#
# /usr/local/lib/python3.10/dist-packages/dataprep/eda/distribution/render.py:274: FutureWarning:
#
# ...

# %%
# EDA - Automated lib

# %%
#! pip install pandas_profiling

# %%
#! pip install markupsafe ==2.0.1

# %%
#from pandas_profiling import ProfileReport

# %%
## to Create the Simple Report quickly

# %%
#profile = ProfileReport(df,title = 'House_Price Prediction',correlations={"cramers": {"calculate": False}}, explorative=True)

# %%
#profile.to_widgets()

# %%
#profile.to_file("HousePrice_Report.html")

# %%
## dtale

# %%
! pip  install dtale

# %%
import dtale

# %%
dtale.show(df)  # click on " d-tale logo" and click " open in new tab"
# Out:
# http://a8fb44ca55c8:40000/dtale/main/3

# %%
df.dropna(inplace=True)

# %%
label = df['price']

# %%
label
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
train = df.drop(['id','price','date'],axis=1)

# %%
train.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
df.corr()
# Out:
# <ipython-input-259-2f6f6606aa2c>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# ...

# %%
corrmat = df.corr()
top_corr_feature = corrmat.index
top_corr_feature
# Out:
# <ipython-input-260-02928e1394e0>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
top_corr_feature = corrmat.index

# %%
plt.figure(figsize=(20,20))
g=sns.heatmap(df[top_corr_feature].corr(),annot=True,cmap="RdYlGn")

# %%
from sklearn.ensemble import ExtraTreesRegressor  #  build a model do prediction give which variable is impacting our depd more
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(train,label)
# Out:
# ExtraTreesRegressor()

# %%
model.feature_importances_
# Out:
# array([0.00806059, 0.03530504, 0.20447351, 0.01256432, 0.0069654 ,
#        0.04043822, 0.03752255, 0.0097996 , 0.24310642, 0.06174011,
#        0.01214006, 0.03674939, 0.00564927, 0.02030473, 0.13803593,
#        0.04754408, 0.06795706, 0.01164369])

# %%
feat_importances = pd.Series(model.feature_importances_, index=train.columns)

# %%
feat_importances
# Out:
# bedrooms         0.008061
# bathrooms        0.035305
# sqft_living      0.204474
# sqft_lot         0.012564
# floors           0.006965
# waterfront       0.040438
# view             0.037523
# condition        0.009800
# grade            0.243106
# sqft_above       0.061740
# sqft_basement    0.012140
# yr_built         0.036749
# yr_renovated     0.005649
# zipcode          0.020305
# lat              0.138036
# long             0.047544
# sqft_living15    0.067957
# sqft_lot15       0.011644
# dtype: float64

# %%
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
col_imp = ['grade','lat','long','sqft_living','waterfront','yr_built']

# %%
train
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0             3       1.00         1180      5650     1.0           0     0
# 1             3       2.25         2570      7242     2.0           0     0
# 2             2       1.00          770     10000     1.0           0     0
# 3             4       3.00         1960      5000     1.0           0     0
# 4             3       2.00         1680      8080     1.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21608         3       2.50         1530      1131     3.0           0     0
# 21609         4       2.50         2310      5813     2.0           0     0
# 21610         2       0.75         1020      1350     2.0           0     0
# 21611         3       2.50         1600      2388     2.0           0     0
# 21612         2       0.75         1020      1076     2.0           0     0
#
# ...

# %%
train[col_imp]
# Out:
#        grade      lat     long  sqft_living  waterfront  yr_built
# 0          7  47.5112 -122.257         1180           0      1955
# 1          7  47.7210 -122.319         2570           0      1951
# 2          6  47.7379 -122.233          770           0      1933
# 3          7  47.5208 -122.393         1960           0      1965
# 4          8  47.6168 -122.045         1680           0      1987
# ...      ...      ...      ...          ...         ...       ...
# 21608      8  47.6993 -122.346         1530           0      2009
# 21609      8  47.5107 -122.362         2310           0      2014
# 21610      7  47.5944 -122.299         1020           0      2009
# 21611      8  47.5345 -122.069         1600           0      2004
# 21612      7  47.5941 -122.299         1020           0      2008
#
# [21613 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train[col_imp], label, test_size=0.3, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor =RandomForestRegressor(n_estimators=500)

# %%
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=500)

# %%
# prediction
y_pred = regressor.predict(train[col_imp])

# %%
y_pred
# Out:
# array([242515.85      , 488186.148     , 225859.644     , ...,
#        334281.29133333, 423060.53133333, 334461.92133333])

# %%
label
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
# rmse ,r2  for comparing model in regression -- classfication ( confusion matrix)

# %%
from sklearn.metrics import mean_squared_error

from math import sqrt

# %%
rmse= sqrt(mean_squared_error(label,y_pred))

# %%
rmse
# Out:
# 85103.44110595588

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
clf = GradientBoostingRegressor(n_estimators =500)

# %%
clf.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(n_estimators=500)

# %%
y_pred_grid = clf.predict(train[col_imp])#gb

# %%
rmse_grid= sqrt(mean_squared_error(label,y_pred_grid))

# %%
rmse_grid
# Out:
# 108564.80493774216

# %%
rmse
# Out:
# 85103.44110595588

# %%
# rf --- saving the ml model   # joblib ,pickle

# %%
import pickle

# %%
pickle.dump(regressor,open('regressor_model.pkl','wb'))

# %%
load = pickle.load(open('regressor_model.pkl','rb'))

# %%
y_loaded = load.predict(train[col_imp])

# %%
y_loaded
# Out:
# array([242515.85      , 488186.148     , 225859.644     , ...,
#        334281.29133333, 423060.53133333, 334461.92133333])

# %%
# !pip install xgboost

# %%
import xgboost as xgb

# %%
xgb_Regressor = xgb.XGBRegressor()

# %%
xgb_Regressor.fit(X_train, y_train)

# %%
y_pred_xgb = xgb_Regressor.predict(train[col_imp])

# %%
y_pred_xgb

# %%
rmse_xgrid= sqrt(mean_squared_error(label,y_pred_xgb))

# %%
rmse_xgrid

# %%
rmse

# %%
# flask -- saved model to create api

# %%
from flask import Flask,request,render_template

# %%
import pickle
import numpy as np
app= Flask(__name__)
#model =pickle.load('regressor_mode.pkl','rb')
#model  =pickle.load(open('regressor_mode.pkl', 'rb'))
#load =  pickle.load(open('regressor_model.pkl','rb'))

# Load the pickled model
with open('regressor_model.pkl','rb') as f:
    model = pickle.load(f)
